# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from numpy.random import randn
import scikitplot as skplt
import warnings
warnings.filterwarnings('ignore')

# %%
path = "C:/Users/Lenovo/Desktop/New folder/Cust.xlsx"

# %%
Cust = pd.read_excel(path)

# %%
Cust
# Out:
#     1Gender of respondent 2 How old are you?   \
# 0                    Male         31-40 years
# 1                  Female         21-30 years
# 2                  Female         21-30 years
# 3                    Male         21-30 years
# 4                  Female         21-30 years
# ..                    ...                 ...
# 264                Female         21-30 years
# 265                Female         31-40 years
# 266                Female         41-50 yaers
# 267                Female  Less than 20 years
# 268                Female         41-50 yaers
#
#     3 Which city do you shop online from?  \
# 0                                   Delhi
# 1                                   Delhi
# 2                           Greater Noida
# 3                                 Karnal
# 4                              Bangalore
# ..                                    ...
# 264                                 Solan
# 265                             Ghaziabad
# ...

# %%
Cust.head()
# Out:
#   1Gender of respondent 2 How old are you?   \
# 0                  Male         31-40 years
# 1                Female         21-30 years
# 2                Female         21-30 years
# 3                  Male         21-30 years
# 4                Female         21-30 years
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#   5 Since How Long You are Shopping Online ?  \
# 0                              Above 4 years
# ...

# %%
a=pd.read_excel('Cust.xlsx')

print(a.describe())

std=np.min(a)
print(std)
# Out:
#        4 What is the Pin Code of where you shop online from?
# count                                         269.000000
# mean                                       220465.747212
# std                                        140524.341051
# min                                        110008.000000
# 25%                                        122018.000000
# 50%                                        201303.000000
# 75%                                        201310.000000
# max                                        560037.000000
# 1Gender of respondent                                                        Female
# 2 How old are you?                                                      21-30 years
# 3 Which city do you shop online from?                                    Bangalore
# 4 What is the Pin Code of where you shop online from?                        110008
# 5 Since How Long You are Shopping Online ?                                1-2 years
# ...

# %%
a=pd.read_excel('Cust.xlsx')

print(a.describe())



cv=np.std(a)/np.mean(a)
print (cv)
# Out:
#        4 What is the Pin Code of where you shop online from?
# count                                         269.000000
# mean                                       220465.747212
# std                                        140524.341051
# min                                        110008.000000
# 25%                                        122018.000000
# 50%                                        201303.000000
# 75%                                        201310.000000
# max                                        560037.000000
# 4 What is the Pin Code of where you shop online from?    0.636212
# dtype: float64

# %%
a=pd.read_excel('Cust.xlsx')

print(a.describe())



cv=np.std(a)/np.mean(a)
print (cv)

b=np.var(a)
print(b)

a.plot(x='Longer delivery period',y='Which of the Indian online retailer would you recommend to a friend?',kind='scatter')
plt.show()
# Out:
#        4 What is the Pin Code of where you shop online from?
# count                                         269.000000
# mean                                       220465.747212
# std                                        140524.341051
# min                                        110008.000000
# 25%                                        122018.000000
# 50%                                        201303.000000
# 75%                                        201310.000000
# max                                        560037.000000
# 4 What is the Pin Code of where you shop online from?    0.636212
# dtype: float64
# 4 What is the Pin Code of where you shop online from?    1.967368e+10
# dtype: float64

# %%
a=pd.read_excel('Cust.xlsx')

print(a.describe())



cv=np.std(a)/np.mean(a)
print (cv)

b=np.var(a)
print(b)

a.plot(x='Longer time in displaying graphics and photos (promotion, sales period)',y='Longer time in displaying graphics and photos (promotion, sales period)',kind='scatter')
plt.show()
# Out:
#        4 What is the Pin Code of where you shop online from?
# count                                         269.000000
# mean                                       220465.747212
# std                                        140524.341051
# min                                        110008.000000
# 25%                                        122018.000000
# 50%                                        201303.000000
# 75%                                        201310.000000
# max                                        560037.000000
# 4 What is the Pin Code of where you shop online from?    0.636212
# dtype: float64
# 4 What is the Pin Code of where you shop online from?    1.967368e+10
# dtype: float64

# %%
a=pd.read_excel('Cust.xlsx')

print(a.describe())



cv=np.std(a)/np.mean(a)
print (cv)

b=np.var(a)
print(b)

a.plot(x='Late declaration of price (promotion, sales period)',y='Longer page loading time (promotion, sales period)',kind='scatter')
plt.show()
# Out:
#        4 What is the Pin Code of where you shop online from?
# count                                         269.000000
# mean                                       220465.747212
# std                                        140524.341051
# min                                        110008.000000
# 25%                                        122018.000000
# 50%                                        201303.000000
# 75%                                        201310.000000
# max                                        560037.000000
# 4 What is the Pin Code of where you shop online from?    0.636212
# dtype: float64
# 4 What is the Pin Code of where you shop online from?    1.967368e+10
# dtype: float64

# %%
a=pd.read_excel('Cust.xlsx')

print(a.describe())



cv=np.std(a)/np.mean(a)
print (cv)

b=np.var(a)
print(b)

a.plot(x='Limited mode of payment on most products (promotion, sales period)',y='Longer delivery period',kind='scatter')
plt.show()
# Out:
#        4 What is the Pin Code of where you shop online from?
# count                                         269.000000
# mean                                       220465.747212
# std                                        140524.341051
# min                                        110008.000000
# 25%                                        122018.000000
# 50%                                        201303.000000
# 75%                                        201310.000000
# max                                        560037.000000
# 4 What is the Pin Code of where you shop online from?    0.636212
# dtype: float64
# 4 What is the Pin Code of where you shop online from?    1.967368e+10
# dtype: float64

# %%
a=pd.read_excel('Cust.xlsx')

print(a.describe())



cv=np.std(a)/np.mean(a)
print (cv)

b=np.var(a)
print(b)

a.plot(x='Change in website/Application design',y='Frequent disruption when moving from one page to another',kind='scatter')
plt.show()
# Out:
#        4 What is the Pin Code of where you shop online from?
# count                                         269.000000
# mean                                       220465.747212
# std                                        140524.341051
# min                                        110008.000000
# 25%                                        122018.000000
# 50%                                        201303.000000
# 75%                                        201310.000000
# max                                        560037.000000
# 4 What is the Pin Code of where you shop online from?    0.636212
# dtype: float64
# 4 What is the Pin Code of where you shop online from?    1.967368e+10
# dtype: float64

# %%
a=pd.read_excel('Cust.xlsx')

print(a.describe())



cv=np.std(a)/np.mean(a)
print (cv)

b=np.var(a)
print(b)

a.plot(x='Website is as efficient as before',y='Which of the Indian online retailer would you recommend to a friend?',kind='scatter')
plt.show()
# Out:
#        4 What is the Pin Code of where you shop online from?
# count                                         269.000000
# mean                                       220465.747212
# std                                        140524.341051
# min                                        110008.000000
# 25%                                        122018.000000
# 50%                                        201303.000000
# 75%                                        201310.000000
# max                                        560037.000000
# 4 What is the Pin Code of where you shop online from?    0.636212
# dtype: float64
# 4 What is the Pin Code of where you shop online from?    1.967368e+10
# dtype: float64

# %% [markdown]
# Cust.describe()

# %%
Cust.mode()
# Out:
#   1Gender of respondent 2 How old are you?   \
# 0                Female         31-40 years
# 1                   NaN                 NaN
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                   NaN
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                           201308.0
# 1                                                NaN
#
#   5 Since How Long You are Shopping Online ?  \
# 0                              Above 4 years
# 1                                        NaN
#
#   6 How many times you have made an online purchase in the past 1 year?  \
# 0                                 Less than 10 times
# 1                                                NaN
#
#   7 How do you access the internet while shopping on-line?  \
# 0                                    Mobile internet
# 1                                                NaN
#
# ...

# %%
Cust.isnull().sum()
# Out:
# 1Gender of respondent                                                   0
# 2 How old are you?                                                      0
# 3 Which city do you shop online from?                                   0
# 4 What is the Pin Code of where you shop online from?                   0
# 5 Since How Long You are Shopping Online ?                              0
#                                                                        ..
# Longer delivery period                                                  0
# Change in website/Application design                                    0
# Frequent disruption when moving from one page to another                0
# Website is as efficient as before                                       0
# Which of the Indian online retailer would you recommend to a friend?    0
# Length: 71, dtype: int64

# %%
Cust.dtypes
# Out:
# 1Gender of respondent                                                   object
# 2 How old are you?                                                      object
# 3 Which city do you shop online from?                                   object
# 4 What is the Pin Code of where you shop online from?                    int64
# 5 Since How Long You are Shopping Online ?                              object
#                                                                          ...
# Longer delivery period                                                  object
# Change in website/Application design                                    object
# Frequent disruption when moving from one page to another                object
# Website is as efficient as before                                       object
# Which of the Indian online retailer would you recommend to a friend?    object
# Length: 71, dtype: object

# %%
Cust['Longer time in displaying graphics and photos (promotion, sales period)'].unique()
# Out:
# array(['Amazon.in', 'Myntra.com', 'Myntra.com, Snapdeal.com', 'Paytm.com',
#        'Amazon.in, Paytm.com', 'Amazon.in, Flipkart.com',
#        'Amazon.in, Myntra.com, Snapdeal.com',
#        'Flipkart.com, Snapdeal.com', 'Snapdeal.com', 'Flipkart.com'],
#       dtype=object)

# %%
Cust['Longer delivery period'].unique()
# Out:
# array(['Paytm.com', 'Snapdeal.com', 'Flipkart.com', 'Amazon.in',
#        'Paytm.com, Snapdeal.com', 'Myntra.com'], dtype=object)

# %%
Cust['Website is as efficient as before'].unique()
# Out:
# array(['Amazon.in', 'Amazon.in, Flipkart.com',
#        'Amazon.in, Flipkart.com, Paytm.com', 'Paytm.com', 'Snapdeal.com',
#        'Myntra.com, Snapdeal.com', 'Flipkart.com', 'Amazon.in, Paytm.com'],
#       dtype=object)

# %%
Cust['Longer delivery period'].astype(str) #convert data to str
# Out:
# 0         Paytm.com
# 1      Snapdeal.com
# 2         Paytm.com
# 3         Paytm.com
# 4         Paytm.com
#            ...
# 264       Amazon.in
# 265    Flipkart.com
# 266    Snapdeal.com
# 267       Amazon.in
# 268       Amazon.in
# Name: Longer delivery period, Length: 269, dtype: object

# %%
Cust.plot.barh()
# Out:
# <AxesSubplot:>

# %%
Cust.plot(kind ='bar')
# Out:
# <AxesSubplot:>

# %%
Cust.plot.bar()
# Out:
# <AxesSubplot:>
